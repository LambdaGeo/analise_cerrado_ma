# %%
import geopandas as gpd
import pandas as pd

# %%
df_micro = gpd.read_file("dados/limites/MA_Microrregioes_2022.zip")
df_micro.set_index("CD_MICRO", inplace=True)
df_micro.head(3)
# Out:
#                                 NM_MICRO SIGLA_UF  AREA_KM2  \
# CD_MICRO
# 21001       Litoral Ocidental Maranhense       MA  8547.145
# 21002     Aglomeração Urbana de São Luís       MA   969.832
# 21003                            Rosário       MA  6007.590
#
#                                                    geometry
# CD_MICRO
# 21001     MULTIPOLYGON (((-44.71062 -2.62729, -44.71043 ...
# 21002     MULTIPOLYGON (((-44.41227 -2.79830, -44.41246 ...
# 21003     MULTIPOLYGON (((-44.07882 -2.74381, -44.07757 ...

# %%
df_micro_desmatamento = gpd.read_file("dados/desmatamento/microregiao_ma_cerrado_desmatamento.zip")
df_micro_desmatamento.set_index("CD_MICRO", inplace=True)
df_micro_desmatamento.head(3)
# Out:
#           inserted_a       area_ha      category_n  porc_cerra source  \
# CD_MICRO
# 21011     2020-02-07  1.984568e+08  Bioma Refinado    0.915295   IBGE
# 21013     2020-02-07  1.984568e+08  Bioma Refinado    1.000845   IBGE
# 21017     2020-02-07  1.984568e+08  Bioma Refinado    1.000009   IBGE
#
#           version    area_cerra                   NM_MICRO  updated_at  \
# CD_MICRO
# 21011           1  33700.677928       Alto Mearim e Graja?  2020-02-07
# 21013           1   6039.736701  Baixo Parna?ba Maranhense  2020-02-07
# 21017           1  15340.102814                     Caxias  2020-02-07
#
#            AREA_KM2 SIGLA_UF     d01-23     name      d2000     id  \
# CD_MICRO
# 21011     36819.486       MA  23.178312  CERRADO  22.969564  18415
# 21013      6034.638       MA  25.398299  CERRADO   9.184563  18415
# 21017     15339.961       MA  32.163859  CERRADO  10.382197  18415
#
#                category                                           geometry
# CD_MICRO
# 21011     refined_biome  MULTIPOLYGON (((-46.79478 -5.87322, -46.79471 ...
# 21013     refined_biome  POLYGON ((-43.16301 -3.43314, -43.16300 -3.432...
# 21017     refined_biome  POLYGON ((-44.07660 -5.83684, -44.07614 -5.836...

# %% [markdown]
# * ao exportar no google earth engine, os nomes com acentos ficaram errados

# %%
df_micro_desmatamento["NM_MICRO"] = df_micro["NM_MICRO"]
df_micro_desmatamento
# Out:
#           inserted_a       area_ha      category_n  porc_cerra source  \
# CD_MICRO
# 21011     2020-02-07  1.984568e+08  Bioma Refinado    0.915295   IBGE
# 21013     2020-02-07  1.984568e+08  Bioma Refinado    1.000845   IBGE
# 21017     2020-02-07  1.984568e+08  Bioma Refinado    1.000009   IBGE
# 21021     2020-02-07  1.984568e+08  Bioma Refinado    0.999321   IBGE
# 21018     2020-02-07  1.984568e+08  Bioma Refinado    0.999590   IBGE
# 21014     2020-02-07  1.984568e+08  Bioma Refinado    1.000162   IBGE
# 21015     2020-02-07  1.984568e+08  Bioma Refinado    0.999515   IBGE
# 21016     2020-02-07  1.984568e+08  Bioma Refinado    1.000125   IBGE
# 21020     2020-02-07  1.984568e+08  Bioma Refinado    0.999754   IBGE
# 21006     2020-02-07  1.984568e+08  Bioma Refinado    0.935117   IBGE
# 21004     2020-02-07  1.984568e+08  Bioma Refinado    0.968079   IBGE
# 21010     2020-02-07  1.984568e+08  Bioma Refinado    0.625860   IBGE
# 21019     2020-02-07  1.984568e+08  Bioma Refinado    1.000586   IBGE
# 21012     2020-02-07  1.984568e+08  Bioma Refinado    0.999390   IBGE
#
#           version    area_cerra                    NM_MICRO  updated_at  \
# CD_MICRO
# 21011           1  33700.677928        Alto Mearim e Grajaú  2020-02-07
# 21013           1   6039.736701   Baixo Parnaíba Maranhense  2020-02-07
# 21017           1  15340.102814                      Caxias  2020-02-07
# 21021           1  16961.316708    Chapadas das Mangabeiras  2020-02-07
# 21018           1  25011.300477  Chapadas do Alto Itapecuru  2020-02-07
# 21014           1  10799.152883                  Chapadinha  2020-02-07
# 21015           1   9914.815626                        Codó  2020-02-07
# 21016           1   3608.482943                 Coelho Neto  2020-02-07
# 21020           1  36657.324079            Gerais de Balsas  2020-02-07
# 21006           1   6609.047340             Itapecuru Mirim  2020-02-07
# 21004           1   9900.023024         Lençóis Maranhenses  2020-02-07
# 21010           1   6886.510594                Médio Mearim  2020-02-07
# 21019           1  14062.460016                Porto Franco  2020-02-07
# 21012           1   6543.504516            Presidente Dutra  2020-02-07
#
#            AREA_KM2 SIGLA_UF     d01-23     name      d2000     id  \
# CD_MICRO
# 21011     36819.486       MA  23.178312  CERRADO  22.969564  18415
# 21013      6034.638       MA  25.398299  CERRADO   9.184563  18415
# 21017     15339.961       MA  32.163859  CERRADO  10.382197  18415
# 21021     16972.844       MA  21.123042  CERRADO   9.242601  18415
# 21018     25021.559       MA  18.649766  CERRADO   5.558591  18415
# 21014     10797.402       MA  27.840742  CERRADO   4.239209  18415
# 21015      9919.623       MA  25.715124  CERRADO  36.283000  18415
# 21016      3608.032       MA  27.220870  CERRADO   6.728744  18415
# 21020     36666.357       MA  21.833064  CERRADO   9.646512  18415
# 21006      7067.616       MA  25.317416  CERRADO  19.379355  18415
# 21004     10226.463       MA  11.250535  CERRADO   2.886642  18415
# 21010     11003.275       MA   4.130432  CERRADO  92.563754  18415
# 21019     14054.223       MA  24.873774  CERRADO  18.327801  18415
# 21012      6547.496       MA  37.403125  CERRADO  44.110667  18415
#
#                category                                           geometry
# CD_MICRO
# 21011     refined_biome  MULTIPOLYGON (((-46.79478 -5.87322, -46.79471 ...
# 21013     refined_biome  POLYGON ((-43.16301 -3.43314, -43.16300 -3.432...
# 21017     refined_biome  POLYGON ((-44.07660 -5.83684, -44.07614 -5.836...
# 21021     refined_biome  POLYGON ((-46.45104 -7.06645, -46.41764 -7.017...
# 21018     refined_biome  POLYGON ((-45.94808 -6.67402, -45.94770 -6.673...
# 21014     refined_biome  POLYGON ((-43.80581 -3.30773, -43.80554 -3.305...
# 21015     refined_biome  POLYGON ((-44.50575 -4.27909, -44.50014 -4.255...
# 21016     refined_biome  POLYGON ((-43.75298 -4.47208, -43.75061 -4.468...
# 21020     refined_biome  POLYGON ((-47.22036 -7.63244, -47.21916 -7.631...
# 21006     refined_biome  POLYGON ((-44.61704 -3.59775, -44.61631 -3.597...
# 21004     refined_biome  POLYGON ((-43.74553 -2.63750, -43.74181 -2.635...
# 21010     refined_biome  POLYGON ((-45.34916 -5.08324, -45.34846 -5.080...
# 21019     refined_biome  POLYGON ((-47.75045 -7.18950, -47.75040 -7.183...
# 21012     refined_biome  POLYGON ((-44.66649 -5.05714, -44.66591 -5.056...

# %%
df_micro_desmatamento.sort_values("porc_cerra").head(3)
# Out:
#           inserted_a       area_ha      category_n  porc_cerra source  \
# CD_MICRO
# 21010     2020-02-07  1.984568e+08  Bioma Refinado    0.625860   IBGE
# 21011     2020-02-07  1.984568e+08  Bioma Refinado    0.915295   IBGE
# 21006     2020-02-07  1.984568e+08  Bioma Refinado    0.935117   IBGE
#
#           version    area_cerra              NM_MICRO  updated_at   AREA_KM2  \
# CD_MICRO
# 21010           1   6886.510594          Médio Mearim  2020-02-07  11003.275
# 21011           1  33700.677928  Alto Mearim e Grajaú  2020-02-07  36819.486
# 21006           1   6609.047340       Itapecuru Mirim  2020-02-07   7067.616
#
#          SIGLA_UF     d01-23     name      d2000     id       category  \
# CD_MICRO
# 21010          MA   4.130432  CERRADO  92.563754  18415  refined_biome
# 21011          MA  23.178312  CERRADO  22.969564  18415  refined_biome
# 21006          MA  25.317416  CERRADO  19.379355  18415  refined_biome
#
#                                                    geometry
# CD_MICRO
# 21010     POLYGON ((-45.34916 -5.08324, -45.34846 -5.080...
# 21011     MULTIPOLYGON (((-46.79478 -5.87322, -46.79471 ...
# 21006     POLYGON ((-44.61704 -3.59775, -44.61631 -3.597...

# %%
df_micro_desmatamento["d00-23"] = df_micro_desmatamento["d2000"] + df_micro_desmatamento["d01-23"]

# %%
df_micro_desmatamento.shape
# Out:
# (14, 18)

# %%
df_micro_desmatamento.head(2)
# Out:
#           inserted_a       area_ha      category_n  porc_cerra source  \
# CD_MICRO
# 21011     2020-02-07  1.984568e+08  Bioma Refinado    0.915295   IBGE
# 21013     2020-02-07  1.984568e+08  Bioma Refinado    1.000845   IBGE
#
#           version    area_cerra                   NM_MICRO  updated_at  \
# CD_MICRO
# 21011           1  33700.677928       Alto Mearim e Grajaú  2020-02-07
# 21013           1   6039.736701  Baixo Parnaíba Maranhense  2020-02-07
#
#            AREA_KM2 SIGLA_UF     d01-23     name      d2000     id  \
# CD_MICRO
# 21011     36819.486       MA  23.178312  CERRADO  22.969564  18415
# 21013      6034.638       MA  25.398299  CERRADO   9.184563  18415
#
#                category                                           geometry  \
# CD_MICRO
# 21011     refined_biome  MULTIPOLYGON (((-46.79478 -5.87322, -46.79471 ...
# 21013     refined_biome  POLYGON ((-43.16301 -3.43314, -43.16300 -3.432...
#
#              d00-23
# CD_MICRO
# 21011     46.147876
# 21013     34.582862

# %%
df_formatar = df_micro_desmatamento.sort_values("d01-23", ascending=False)[["NM_MICRO","area_cerra","d2000", "d00-23","d01-23"]].set_index("NM_MICRO")
df_formatar
# Out:
#                               area_cerra      d2000     d00-23     d01-23
# NM_MICRO
# Presidente Dutra             6543.504516  44.110667  81.513792  37.403125
# Caxias                      15340.102814  10.382197  42.546056  32.163859
# Chapadinha                  10799.152883   4.239209  32.079951  27.840742
# Coelho Neto                  3608.482943   6.728744  33.949615  27.220870
# Codó                         9914.815626  36.283000  61.998124  25.715124
# Baixo Parnaíba Maranhense    6039.736701   9.184563  34.582862  25.398299
# Itapecuru Mirim              6609.047340  19.379355  44.696771  25.317416
# Porto Franco                14062.460016  18.327801  43.201575  24.873774
# Alto Mearim e Grajaú        33700.677928  22.969564  46.147876  23.178312
# Gerais de Balsas            36657.324079   9.646512  31.479576  21.833064
# Chapadas das Mangabeiras    16961.316708   9.242601  30.365642  21.123042
# Chapadas do Alto Itapecuru  25011.300477   5.558591  24.208357  18.649766
# Lençóis Maranhenses          9900.023024   2.886642  14.137177  11.250535
# Médio Mearim                 6886.510594  92.563754  96.694186   4.130432

# %%
df_formatar.columns = ["Área (km²)", "2000 (%)", "2023 (%)", "Diferença (%)"]
df_formatar.index.name = "Nome"
df_formatar.head()
# Out:
#                     Área (km²)   2000 (%)   2023 (%)  Diferença (%)
# Nome
# Presidente Dutra   6543.504516  44.110667  81.513792      37.403125
# Caxias            15340.102814  10.382197  42.546056      32.163859
# Chapadinha        10799.152883   4.239209  32.079951      27.840742
# Coelho Neto        3608.482943   6.728744  33.949615      27.220870
# Codó               9914.815626  36.283000  61.998124      25.715124

# %%
s = df_formatar.style
s
# Out:
# <style type="text/css">
# </style>
# <table id="T_9e46c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e46c_level0_col0" class="col_heading level0 col0" >Área (km²)</th>
#       <th id="T_9e46c_level0_col1" class="col_heading level0 col1" >2000 (%)</th>
#       <th id="T_9e46c_level0_col2" class="col_heading level0 col2" >2023 (%)</th>
#       <th id="T_9e46c_level0_col3" class="col_heading level0 col3" >Diferença (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Nome</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e46c_level0_row0" class="row_heading level0 row0" >Presidente Dutra</th>
#       <td id="T_9e46c_row0_col0" class="data row0 col0" >6543.504516</td>
#       <td id="T_9e46c_row0_col1" class="data row0 col1" >44.110667</td>
#       <td id="T_9e46c_row0_col2" class="data row0 col2" >81.513792</td>
#       <td id="T_9e46c_row0_col3" class="data row0 col3" >37.403125</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row1" class="row_heading level0 row1" >Caxias</th>
#       <td id="T_9e46c_row1_col0" class="data row1 col0" >15340.102814</td>
#       <td id="T_9e46c_row1_col1" class="data row1 col1" >10.382197</td>
#       <td id="T_9e46c_row1_col2" class="data row1 col2" >42.546056</td>
#       <td id="T_9e46c_row1_col3" class="data row1 col3" >32.163859</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row2" class="row_heading level0 row2" >Chapadinha</th>
#       <td id="T_9e46c_row2_col0" class="data row2 col0" >10799.152883</td>
#       <td id="T_9e46c_row2_col1" class="data row2 col1" >4.239209</td>
#       <td id="T_9e46c_row2_col2" class="data row2 col2" >32.079951</td>
#       <td id="T_9e46c_row2_col3" class="data row2 col3" >27.840742</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row3" class="row_heading level0 row3" >Coelho Neto</th>
#       <td id="T_9e46c_row3_col0" class="data row3 col0" >3608.482943</td>
#       <td id="T_9e46c_row3_col1" class="data row3 col1" >6.728744</td>
#       <td id="T_9e46c_row3_col2" class="data row3 col2" >33.949615</td>
#       <td id="T_9e46c_row3_col3" class="data row3 col3" >27.220870</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row4" class="row_heading level0 row4" >Codó</th>
#       <td id="T_9e46c_row4_col0" class="data row4 col0" >9914.815626</td>
#       <td id="T_9e46c_row4_col1" class="data row4 col1" >36.283000</td>
#       <td id="T_9e46c_row4_col2" class="data row4 col2" >61.998124</td>
#       <td id="T_9e46c_row4_col3" class="data row4 col3" >25.715124</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row5" class="row_heading level0 row5" >Baixo Parnaíba Maranhense</th>
#       <td id="T_9e46c_row5_col0" class="data row5 col0" >6039.736701</td>
#       <td id="T_9e46c_row5_col1" class="data row5 col1" >9.184563</td>
#       <td id="T_9e46c_row5_col2" class="data row5 col2" >34.582862</td>
#       <td id="T_9e46c_row5_col3" class="data row5 col3" >25.398299</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row6" class="row_heading level0 row6" >Itapecuru Mirim</th>
#       <td id="T_9e46c_row6_col0" class="data row6 col0" >6609.047340</td>
#       <td id="T_9e46c_row6_col1" class="data row6 col1" >19.379355</td>
#       <td id="T_9e46c_row6_col2" class="data row6 col2" >44.696771</td>
#       <td id="T_9e46c_row6_col3" class="data row6 col3" >25.317416</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row7" class="row_heading level0 row7" >Porto Franco</th>
#       <td id="T_9e46c_row7_col0" class="data row7 col0" >14062.460016</td>
#       <td id="T_9e46c_row7_col1" class="data row7 col1" >18.327801</td>
#       <td id="T_9e46c_row7_col2" class="data row7 col2" >43.201575</td>
#       <td id="T_9e46c_row7_col3" class="data row7 col3" >24.873774</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row8" class="row_heading level0 row8" >Alto Mearim e Grajaú</th>
#       <td id="T_9e46c_row8_col0" class="data row8 col0" >33700.677928</td>
#       <td id="T_9e46c_row8_col1" class="data row8 col1" >22.969564</td>
#       <td id="T_9e46c_row8_col2" class="data row8 col2" >46.147876</td>
#       <td id="T_9e46c_row8_col3" class="data row8 col3" >23.178312</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row9" class="row_heading level0 row9" >Gerais de Balsas</th>
#       <td id="T_9e46c_row9_col0" class="data row9 col0" >36657.324079</td>
#       <td id="T_9e46c_row9_col1" class="data row9 col1" >9.646512</td>
#       <td id="T_9e46c_row9_col2" class="data row9 col2" >31.479576</td>
#       <td id="T_9e46c_row9_col3" class="data row9 col3" >21.833064</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row10" class="row_heading level0 row10" >Chapadas das Mangabeiras</th>
#       <td id="T_9e46c_row10_col0" class="data row10 col0" >16961.316708</td>
#       <td id="T_9e46c_row10_col1" class="data row10 col1" >9.242601</td>
#       <td id="T_9e46c_row10_col2" class="data row10 col2" >30.365642</td>
#       <td id="T_9e46c_row10_col3" class="data row10 col3" >21.123042</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row11" class="row_heading level0 row11" >Chapadas do Alto Itapecuru</th>
#       <td id="T_9e46c_row11_col0" class="data row11 col0" >25011.300477</td>
#       <td id="T_9e46c_row11_col1" class="data row11 col1" >5.558591</td>
#       <td id="T_9e46c_row11_col2" class="data row11 col2" >24.208357</td>
#       <td id="T_9e46c_row11_col3" class="data row11 col3" >18.649766</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row12" class="row_heading level0 row12" >Lençóis Maranhenses</th>
#       <td id="T_9e46c_row12_col0" class="data row12 col0" >9900.023024</td>
#       <td id="T_9e46c_row12_col1" class="data row12 col1" >2.886642</td>
#       <td id="T_9e46c_row12_col2" class="data row12 col2" >14.137177</td>
#       <td id="T_9e46c_row12_col3" class="data row12 col3" >11.250535</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row13" class="row_heading level0 row13" >Médio Mearim</th>
#       <td id="T_9e46c_row13_col0" class="data row13 col0" >6886.510594</td>
#       <td id="T_9e46c_row13_col1" class="data row13 col1" >92.563754</td>
#       <td id="T_9e46c_row13_col2" class="data row13 col2" >96.694186</td>
#       <td id="T_9e46c_row13_col3" class="data row13 col3" >4.130432</td>
#     </tr>
#   </tbody>
# </table>

# %%
def formatar_valor(valor):
    return '{:,.1f}'.format(valor).replace(',', 'X').replace('.', ',').replace('X', '.')

# %%
#df_formatar.columns = ["Área (km²)", "2000 (%)", "2023 (%)", "Diferença (%)"]

s.format({
        'Área (km²)':formatar_valor,
        '2000 (%)' : '{:.0f}%',
        '2023 (%)' : '{:.0f}%',
        'Diferença (%)':'{:.0f}%'
    }).highlight_max(color='cornflowerblue').highlight_min(color ='lightblue')
# Out:
# <style type="text/css">
# #T_9e46c_row0_col3, #T_9e46c_row9_col0, #T_9e46c_row13_col1, #T_9e46c_row13_col2 {
#   background-color: darkblue;
#   background-color: darkblue;
#   background-color: darkblue;
#   background-color: darkblue3;
#   background-color: darkblue1;
#   background-color: darkblue1;
#   background-color: darkblue_1;
#   background-color: darkblue_1ww;
#   background-color: darkblue_1ww;
#   background-color: green;
#   background-color: blue;
#   background-color: royalblue;
#   background-color: cornflowerblue;
#   background-color: cornflowerblue;
#   background-color: cornflowerblue;
# }
# #T_9e46c_row3_col0, #T_9e46c_row12_col1, #T_9e46c_row12_col2, #T_9e46c_row13_col3 {
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
# }
# </style>
# <table id="T_9e46c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e46c_level0_col0" class="col_heading level0 col0" >Área (km²)</th>
#       <th id="T_9e46c_level0_col1" class="col_heading level0 col1" >2000 (%)</th>
#       <th id="T_9e46c_level0_col2" class="col_heading level0 col2" >2023 (%)</th>
#       <th id="T_9e46c_level0_col3" class="col_heading level0 col3" >Diferença (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Nome</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e46c_level0_row0" class="row_heading level0 row0" >Presidente Dutra</th>
#       <td id="T_9e46c_row0_col0" class="data row0 col0" >6.543,5</td>
#       <td id="T_9e46c_row0_col1" class="data row0 col1" >44%</td>
#       <td id="T_9e46c_row0_col2" class="data row0 col2" >82%</td>
#       <td id="T_9e46c_row0_col3" class="data row0 col3" >37%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row1" class="row_heading level0 row1" >Caxias</th>
#       <td id="T_9e46c_row1_col0" class="data row1 col0" >15.340,1</td>
#       <td id="T_9e46c_row1_col1" class="data row1 col1" >10%</td>
#       <td id="T_9e46c_row1_col2" class="data row1 col2" >43%</td>
#       <td id="T_9e46c_row1_col3" class="data row1 col3" >32%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row2" class="row_heading level0 row2" >Chapadinha</th>
#       <td id="T_9e46c_row2_col0" class="data row2 col0" >10.799,2</td>
#       <td id="T_9e46c_row2_col1" class="data row2 col1" >4%</td>
#       <td id="T_9e46c_row2_col2" class="data row2 col2" >32%</td>
#       <td id="T_9e46c_row2_col3" class="data row2 col3" >28%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row3" class="row_heading level0 row3" >Coelho Neto</th>
#       <td id="T_9e46c_row3_col0" class="data row3 col0" >3.608,5</td>
#       <td id="T_9e46c_row3_col1" class="data row3 col1" >7%</td>
#       <td id="T_9e46c_row3_col2" class="data row3 col2" >34%</td>
#       <td id="T_9e46c_row3_col3" class="data row3 col3" >27%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row4" class="row_heading level0 row4" >Codó</th>
#       <td id="T_9e46c_row4_col0" class="data row4 col0" >9.914,8</td>
#       <td id="T_9e46c_row4_col1" class="data row4 col1" >36%</td>
#       <td id="T_9e46c_row4_col2" class="data row4 col2" >62%</td>
#       <td id="T_9e46c_row4_col3" class="data row4 col3" >26%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row5" class="row_heading level0 row5" >Baixo Parnaíba Maranhense</th>
#       <td id="T_9e46c_row5_col0" class="data row5 col0" >6.039,7</td>
#       <td id="T_9e46c_row5_col1" class="data row5 col1" >9%</td>
#       <td id="T_9e46c_row5_col2" class="data row5 col2" >35%</td>
#       <td id="T_9e46c_row5_col3" class="data row5 col3" >25%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row6" class="row_heading level0 row6" >Itapecuru Mirim</th>
#       <td id="T_9e46c_row6_col0" class="data row6 col0" >6.609,0</td>
#       <td id="T_9e46c_row6_col1" class="data row6 col1" >19%</td>
#       <td id="T_9e46c_row6_col2" class="data row6 col2" >45%</td>
#       <td id="T_9e46c_row6_col3" class="data row6 col3" >25%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row7" class="row_heading level0 row7" >Porto Franco</th>
#       <td id="T_9e46c_row7_col0" class="data row7 col0" >14.062,5</td>
#       <td id="T_9e46c_row7_col1" class="data row7 col1" >18%</td>
#       <td id="T_9e46c_row7_col2" class="data row7 col2" >43%</td>
#       <td id="T_9e46c_row7_col3" class="data row7 col3" >25%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row8" class="row_heading level0 row8" >Alto Mearim e Grajaú</th>
#       <td id="T_9e46c_row8_col0" class="data row8 col0" >33.700,7</td>
#       <td id="T_9e46c_row8_col1" class="data row8 col1" >23%</td>
#       <td id="T_9e46c_row8_col2" class="data row8 col2" >46%</td>
#       <td id="T_9e46c_row8_col3" class="data row8 col3" >23%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row9" class="row_heading level0 row9" >Gerais de Balsas</th>
#       <td id="T_9e46c_row9_col0" class="data row9 col0" >36.657,3</td>
#       <td id="T_9e46c_row9_col1" class="data row9 col1" >10%</td>
#       <td id="T_9e46c_row9_col2" class="data row9 col2" >31%</td>
#       <td id="T_9e46c_row9_col3" class="data row9 col3" >22%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row10" class="row_heading level0 row10" >Chapadas das Mangabeiras</th>
#       <td id="T_9e46c_row10_col0" class="data row10 col0" >16.961,3</td>
#       <td id="T_9e46c_row10_col1" class="data row10 col1" >9%</td>
#       <td id="T_9e46c_row10_col2" class="data row10 col2" >30%</td>
#       <td id="T_9e46c_row10_col3" class="data row10 col3" >21%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row11" class="row_heading level0 row11" >Chapadas do Alto Itapecuru</th>
#       <td id="T_9e46c_row11_col0" class="data row11 col0" >25.011,3</td>
#       <td id="T_9e46c_row11_col1" class="data row11 col1" >6%</td>
#       <td id="T_9e46c_row11_col2" class="data row11 col2" >24%</td>
#       <td id="T_9e46c_row11_col3" class="data row11 col3" >19%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row12" class="row_heading level0 row12" >Lençóis Maranhenses</th>
#       <td id="T_9e46c_row12_col0" class="data row12 col0" >9.900,0</td>
#       <td id="T_9e46c_row12_col1" class="data row12 col1" >3%</td>
#       <td id="T_9e46c_row12_col2" class="data row12 col2" >14%</td>
#       <td id="T_9e46c_row12_col3" class="data row12 col3" >11%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row13" class="row_heading level0 row13" >Médio Mearim</th>
#       <td id="T_9e46c_row13_col0" class="data row13 col0" >6.886,5</td>
#       <td id="T_9e46c_row13_col1" class="data row13 col1" >93%</td>
#       <td id="T_9e46c_row13_col2" class="data row13 col2" >97%</td>
#       <td id="T_9e46c_row13_col3" class="data row13 col3" >4%</td>
#     </tr>
#   </tbody>
# </table>

# %%
print (s.to_html())
# Out:
# <style type="text/css">
# #T_9e46c_row0_col3, #T_9e46c_row9_col0, #T_9e46c_row13_col1, #T_9e46c_row13_col2 {
#   background-color: darkblue;
#   background-color: darkblue;
#   background-color: darkblue;
#   background-color: darkblue3;
#   background-color: darkblue1;
#   background-color: darkblue1;
#   background-color: darkblue_1;
#   background-color: darkblue_1ww;
#   background-color: darkblue_1ww;
#   background-color: green;
#   background-color: blue;
#   background-color: royalblue;
#   background-color: cornflowerblue;
#   background-color: cornflowerblue;
#   background-color: cornflowerblue;
# }
# #T_9e46c_row3_col0, #T_9e46c_row12_col1, #T_9e46c_row12_col2, #T_9e46c_row13_col3 {
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
#   background-color: lightblue;
# }
# </style>
# <table id="T_9e46c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e46c_level0_col0" class="col_heading level0 col0" >Área (km²)</th>
#       <th id="T_9e46c_level0_col1" class="col_heading level0 col1" >2000 (%)</th>
#       <th id="T_9e46c_level0_col2" class="col_heading level0 col2" >2023 (%)</th>
#       <th id="T_9e46c_level0_col3" class="col_heading level0 col3" >Diferença (%)</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Nome</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e46c_level0_row0" class="row_heading level0 row0" >Presidente Dutra</th>
#       <td id="T_9e46c_row0_col0" class="data row0 col0" >6.543,5</td>
#       <td id="T_9e46c_row0_col1" class="data row0 col1" >44%</td>
#       <td id="T_9e46c_row0_col2" class="data row0 col2" >82%</td>
#       <td id="T_9e46c_row0_col3" class="data row0 col3" >37%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row1" class="row_heading level0 row1" >Caxias</th>
#       <td id="T_9e46c_row1_col0" class="data row1 col0" >15.340,1</td>
#       <td id="T_9e46c_row1_col1" class="data row1 col1" >10%</td>
#       <td id="T_9e46c_row1_col2" class="data row1 col2" >43%</td>
#       <td id="T_9e46c_row1_col3" class="data row1 col3" >32%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row2" class="row_heading level0 row2" >Chapadinha</th>
#       <td id="T_9e46c_row2_col0" class="data row2 col0" >10.799,2</td>
#       <td id="T_9e46c_row2_col1" class="data row2 col1" >4%</td>
#       <td id="T_9e46c_row2_col2" class="data row2 col2" >32%</td>
#       <td id="T_9e46c_row2_col3" class="data row2 col3" >28%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row3" class="row_heading level0 row3" >Coelho Neto</th>
#       <td id="T_9e46c_row3_col0" class="data row3 col0" >3.608,5</td>
#       <td id="T_9e46c_row3_col1" class="data row3 col1" >7%</td>
#       <td id="T_9e46c_row3_col2" class="data row3 col2" >34%</td>
#       <td id="T_9e46c_row3_col3" class="data row3 col3" >27%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row4" class="row_heading level0 row4" >Codó</th>
#       <td id="T_9e46c_row4_col0" class="data row4 col0" >9.914,8</td>
#       <td id="T_9e46c_row4_col1" class="data row4 col1" >36%</td>
#       <td id="T_9e46c_row4_col2" class="data row4 col2" >62%</td>
#       <td id="T_9e46c_row4_col3" class="data row4 col3" >26%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row5" class="row_heading level0 row5" >Baixo Parnaíba Maranhense</th>
#       <td id="T_9e46c_row5_col0" class="data row5 col0" >6.039,7</td>
#       <td id="T_9e46c_row5_col1" class="data row5 col1" >9%</td>
#       <td id="T_9e46c_row5_col2" class="data row5 col2" >35%</td>
#       <td id="T_9e46c_row5_col3" class="data row5 col3" >25%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row6" class="row_heading level0 row6" >Itapecuru Mirim</th>
#       <td id="T_9e46c_row6_col0" class="data row6 col0" >6.609,0</td>
#       <td id="T_9e46c_row6_col1" class="data row6 col1" >19%</td>
#       <td id="T_9e46c_row6_col2" class="data row6 col2" >45%</td>
#       <td id="T_9e46c_row6_col3" class="data row6 col3" >25%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row7" class="row_heading level0 row7" >Porto Franco</th>
#       <td id="T_9e46c_row7_col0" class="data row7 col0" >14.062,5</td>
#       <td id="T_9e46c_row7_col1" class="data row7 col1" >18%</td>
#       <td id="T_9e46c_row7_col2" class="data row7 col2" >43%</td>
#       <td id="T_9e46c_row7_col3" class="data row7 col3" >25%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row8" class="row_heading level0 row8" >Alto Mearim e Grajaú</th>
#       <td id="T_9e46c_row8_col0" class="data row8 col0" >33.700,7</td>
#       <td id="T_9e46c_row8_col1" class="data row8 col1" >23%</td>
#       <td id="T_9e46c_row8_col2" class="data row8 col2" >46%</td>
#       <td id="T_9e46c_row8_col3" class="data row8 col3" >23%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row9" class="row_heading level0 row9" >Gerais de Balsas</th>
#       <td id="T_9e46c_row9_col0" class="data row9 col0" >36.657,3</td>
#       <td id="T_9e46c_row9_col1" class="data row9 col1" >10%</td>
#       <td id="T_9e46c_row9_col2" class="data row9 col2" >31%</td>
#       <td id="T_9e46c_row9_col3" class="data row9 col3" >22%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row10" class="row_heading level0 row10" >Chapadas das Mangabeiras</th>
#       <td id="T_9e46c_row10_col0" class="data row10 col0" >16.961,3</td>
#       <td id="T_9e46c_row10_col1" class="data row10 col1" >9%</td>
#       <td id="T_9e46c_row10_col2" class="data row10 col2" >30%</td>
#       <td id="T_9e46c_row10_col3" class="data row10 col3" >21%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row11" class="row_heading level0 row11" >Chapadas do Alto Itapecuru</th>
#       <td id="T_9e46c_row11_col0" class="data row11 col0" >25.011,3</td>
#       <td id="T_9e46c_row11_col1" class="data row11 col1" >6%</td>
#       <td id="T_9e46c_row11_col2" class="data row11 col2" >24%</td>
#       <td id="T_9e46c_row11_col3" class="data row11 col3" >19%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row12" class="row_heading level0 row12" >Lençóis Maranhenses</th>
#       <td id="T_9e46c_row12_col0" class="data row12 col0" >9.900,0</td>
#       <td id="T_9e46c_row12_col1" class="data row12 col1" >3%</td>
#       <td id="T_9e46c_row12_col2" class="data row12 col2" >14%</td>
#       <td id="T_9e46c_row12_col3" class="data row12 col3" >11%</td>
#     </tr>
#     <tr>
#       <th id="T_9e46c_level0_row13" class="row_heading level0 row13" >Médio Mearim</th>
#       <td id="T_9e46c_row13_col0" class="data row13 col0" >6.886,5</td>
#       <td id="T_9e46c_row13_col1" class="data row13 col1" >93%</td>
#       <td id="T_9e46c_row13_col2" class="data row13 col2" >97%</td>
#       <td id="T_9e46c_row13_col3" class="data row13 col3" >4%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## visualizando no espaço

# %%
df_micro_desmatamento.head(3)
# Out:
#           inserted_a       area_ha      category_n  porc_cerra source  \
# CD_MICRO
# 21011     2020-02-07  1.984568e+08  Bioma Refinado    0.915295   IBGE
# 21013     2020-02-07  1.984568e+08  Bioma Refinado    1.000845   IBGE
# 21017     2020-02-07  1.984568e+08  Bioma Refinado    1.000009   IBGE
#
#           version    area_cerra                   NM_MICRO  updated_at  \
# CD_MICRO
# 21011           1  33700.677928       Alto Mearim e Grajaú  2020-02-07
# 21013           1   6039.736701  Baixo Parnaíba Maranhense  2020-02-07
# 21017           1  15340.102814                     Caxias  2020-02-07
#
#            AREA_KM2 SIGLA_UF     d01-23     name      d2000     id  \
# CD_MICRO
# 21011     36819.486       MA  23.178312  CERRADO  22.969564  18415
# 21013      6034.638       MA  25.398299  CERRADO   9.184563  18415
# 21017     15339.961       MA  32.163859  CERRADO  10.382197  18415
#
#                category                                           geometry  \
# CD_MICRO
# 21011     refined_biome  MULTIPOLYGON (((-46.79478 -5.87322, -46.79471 ...
# 21013     refined_biome  POLYGON ((-43.16301 -3.43314, -43.16300 -3.432...
# 21017     refined_biome  POLYGON ((-44.07660 -5.83684, -44.07614 -5.836...
#
#              d00-23
# CD_MICRO
# 21011     46.147876
# 21013     34.582862
# 21017     42.546056

# %%
ax = df_micro_desmatamento.plot(
    column="d2000",  # Data to plot
    scheme="quantiles",  # Classification scheme
    k=10,
    cmap="Reds",  # Color palette
    legend=True,  # Add legend
    #legend_kwds={"fmt": "{:.0f}"},  # Remove decimals in legend
    figsize=(10,100)
)
ax.set_axis_off()

# %%
import folium

# %%
mapa = folium.Map(location = [-4.4671541,-43.9278995,],
                      zoom_start = 7,
                      tiles = 'OpenStreetMap')

folium.Choropleth(geo_data = df_micro_desmatamento,
                  data= df_micro_desmatamento,
                  columns = ['NM_MICRO','d01-23'],
                  key_on = 'feature.properties.NM_MICRO',
                  fill_color = 'Blues',
                  nan_fill_color = 'white',
                  bins = 10,
                  highlight = True,
                  legend_name = 'Porcentagem de Desmatamento').add_to(mapa)

# Adicionando controle de camadas
#folium.LayerControl().add_to(mapa)


mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6adb45426f843ee532605a66f45295c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6adb45426f843ee532605a66f45295c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6adb45426f843ee532605a66f45295c3 = L.map(
#                 &quot;map_6adb45426f843ee532605a66f45295c3&quot;,
#                 {
#                     center: [-4.4671541, -43.9278995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2ceeb38d9014163e300065dd596f311 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e2ceeb38d9014163e300065dd596f311.addTo(map_6adb45426f843ee532605a66f45295c3);
#
#
#             var choropleth_066789c597f6aa616a08351a49246174 = L.featureGroup(
#                 {}
#             );
#
#
#         function geo_json_b058abd13dee6a978ea59337ee0c7db8_styler(feature) {
#             switch(feature.id) {
#                 case &quot;21011&quot;: case &quot;21021&quot;: case &quot;21020&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#58a1ce&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;21013&quot;: case &quot;21015&quot;: case &quot;21016&quot;: case &quot;21006&quot;: case &quot;21019&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#3787c0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;21017&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#084d96&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;21014&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1b69af&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;21004&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#cbdef0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;21010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f7fbff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;21012&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08306b&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#81bada&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#         function geo_json_b058abd13dee6a978ea59337ee0c7db8_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.8, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_b058abd13dee6a978ea59337ee0c7db8_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_b058abd13dee6a978ea59337ee0c7db8.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b058abd13dee6a978ea59337ee0c7db8_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b058abd13dee6a978ea59337ee0c7db8 = L.geoJson(null, {
#                 onEachFeature: geo_json_b058abd13dee6a978ea59337ee0c7db8_onEachFeature,
#
#                 style: geo_json_b058abd13dee6a978ea59337ee0c7db8_styler,
#         });
#
#         function geo_json_b058abd13dee6a978ea59337ee0c7db8_add (data) {
#             geo_json_b058abd13dee6a978ea59337ee0c7db8
#                 .addData(data);
#         }
#             geo_json_b058abd13dee6a978ea59337ee0c7db8_add({&quot;bbox&quot;: [-47.750449495769615, -10.261765586139612, -41.79606865449423, -2.335485264883277], &quot;features&quot;: [{&quot;bbox&quot;: [-46.79477633718894, -6.912660204204757, -44.4472686349188, -4.8560186502996805], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-46.79477633718894, -5.873224221247569], [-46.79471340901751, -5.871774689311605], [-

# %%
df_micro.plot()
# Out:
# <Axes: >
